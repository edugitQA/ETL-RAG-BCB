# %%
# qa_system.py

from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
import json
import os

# ======= CONFIGURAÇÃO INICIAL =======
load_dotenv()

# Carrega configurações externas
def load_settings():
    with open("../configs/settings.json", "r") as f:
        return json.load(f)

settings = load_settings()
openai_api_key = os.getenv("OPENAI_API_KEY") or settings.get("openai_api_key")
vectorstore_dir = os.path.abspath("../vectorstore")
collection_name = "documents_dados_bcb"

if not openai_api_key:
    raise ValueError("Chave da API OpenAI não encontrada.")

# ======= EMBEDDING E VECTORSTORE =======
def load_vectorstore():
    print(f"📁 Carregando base vetorial de: {vectorstore_dir}")
    embedding = OpenAIEmbeddings(api_key=openai_api_key)
    
    try:
        vectorstore = Chroma(
            collection_name=collection_name,
            persist_directory=vectorstore_dir,
            embedding_function=embedding
        )
        print("✅ Base vetorial carregada com sucesso.")
        return vectorstore
    except Exception as e:
        raise RuntimeError(f"Erro ao carregar vectorstore: {e}")

# ======= PROMPT TEMPLATE =======
prompt_template = PromptTemplate(
    template="""Com base no contexto fornecido, responda à pergunta de forma precisa e detalhada.

Contexto:
{context}

Pergunta: {question}

Responda de forma clara e específica, citando dados quando disponíveis. Se não encontrar a informação no contexto, informe isso.

Resposta:""",
    input_variables=["context", "question"]
)

# ======= INICIALIZAÇÃO DO SISTEMA QA =======
def init_qa_system():
    print("🤖 Inicializando sistema Q&A...")
    
    vectorstore = load_vectorstore()

    retriever = vectorstore.as_retriever(
        search_type="similarity",
        search_kwargs={"k":10}
    )

    llm = ChatOpenAI(model="gpt-4o", temperature=0, api_key=openai_api_key)

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        chain_type_kwargs={"prompt": prompt_template},
        return_source_documents=True
    )

    return qa_chain, vectorstore

# ======= FUNÇÃO DE PERGUNTA =======
def ask_question(question, qa_chain, vectorstore):
    print(f"\n🔎 Pergunta: {question}")
    print("-" * 50)
    
    try:
        # Busca direta para avaliar score
        direct_results = vectorstore.similarity_search_with_score(question, k=3)
        print(f"🔍 Busca direta encontrou {len(direct_results)} resultados")

        if direct_results:
            best_score = direct_results[0][1]
            relevance = "🟢 Alta" if best_score < 0.8 else "🟡 Média" if best_score < 1.2 else "🔴 Baixa"
            print(f"📊 Melhor score: {best_score:.3f} - Relevância: {relevance}")

        # Executa o QA chain
        response = qa_chain({"query": question})
        print(f"\n💬 Resposta:\n{response['result']}")
        print(f"\n📚 Baseado em {len(response['source_documents'])} documento(s):")

        for i, doc in enumerate(response['source_documents'][:3]):
            print(f"\n📄 Fonte {i+1}:\n{doc.page_content[:300]}...")

        return response

    except Exception as e:
        print(f"❌ Erro ao processar pergunta: {e}")
        return None

# ======= TESTE INICIAL (main) =======
if __name__ == "__main__":
    print("=" * 60)
    print("SISTEMA Q&A FUNCIONAL - PRONTO PARA USO!")
    print("=" * 60)

    qa_chain, vectorstore = init_qa_system()

    test_questions = [
        "Qual era o valor da série em dezembro de 2002?",
        "Quais dados estão disponíveis para dezembro de 2002?",
        "Há informações sobre séries temporais em 2002?",
        "Que tipo de dados financeiros estão disponíveis?"
    ]

    for question in test_questions:
        response = ask_question(question, qa_chain, vectorstore)
        print("\n" + "─" * 60)

        if response:
            if "não encontrei" in response['result'].lower() or "não está disponível" in response['result'].lower():
                print("⚠️ Informação não encontrada - pode precisar verificar os dados originais")
            else:
                print("✅ Resposta obtida com sucesso")

    print("\n✨ Testes concluídos!")
    print("Use a função `ask_question('sua pergunta', qa_chain, vectorstore)` para novas consultas.")
# Out:
# ============================================================
# SISTEMA Q&A FUNCIONAL - PRONTO PARA USO!
# ============================================================
# 🤖 Inicializando sistema Q&A...
# 📁 Carregando base vetorial de: /home/edu/Documentos/Engenharia-dados-IA/Pipe-Rag/vectorstore
# ✅ Base vetorial carregada com sucesso.
#
# 🔎 Pergunta: Qual era o valor da série em dezembro de 2002?
# --------------------------------------------------
#
# 🔎 Pergunta: Qual era o valor da série em dezembro de 2002?
# --------------------------------------------------
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.210 - Relevância: 🟢 Alta
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.210 - Relevância: 🟢 Alta
#
# 💬 Resposta:
# O valor da série em dezembro de 2002 era R$ 477899,39.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2002-12-01
# valor: 47789939
# contexto: No mês de dezembro de 2002, o valor da série era R$ 477899,39....
#
# 📄 Fonte 2:
# data: 1992-12-01
# valor: 40373603409
# contexto: No mês de dezembro de 1992, o valor da série era R$ 403736034,09....
#
# 📄 Fonte 3:
# data: 2006-12-01
# valor: 82881420
# contexto: No mês de dezembro de 2006, o valor da série era R$ 828814,20....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# 🔎 Pergunta: Quais dados estão disponíveis para dezembro de 2002?
# --------------------------------------------------
#
# 💬 Resposta:
# O valor da série em dezembro de 2002 era R$ 477899,39.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2002-12-01
# valor: 47789939
# contexto: No mês de dezembro de 2002, o valor da série era R$ 477899,39....
#
# 📄 Fonte 2:
# data: 1992-12-01
# valor: 40373603409
# contexto: No mês de dezembro de 1992, o valor da série era R$ 403736034,09....
#
# 📄 Fonte 3:
# data: 2006-12-01
# valor: 82881420
# contexto: No mês de dezembro de 2006, o valor da série era R$ 828814,20....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# 🔎 Pergunta: Quais dados estão disponíveis para dezembro de 2002?
# --------------------------------------------------
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.314 - Relevância: 🟢 Alta
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.314 - Relevância: 🟢 Alta
#
# 💬 Resposta:
# Para dezembro de 2002, o dado disponível é que o valor da série era R$ 477899,39.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2002-12-01
# valor: 47789939
# contexto: No mês de dezembro de 2002, o valor da série era R$ 477899,39....
#
# 📄 Fonte 2:
# data: 2003-12-01
# valor: 50092791
# contexto: No mês de dezembro de 2003, o valor da série era R$ 500927,91....
#
# 📄 Fonte 3:
# data: 2001-12-01
# valor: 35870597
# contexto: No mês de dezembro de 2001, o valor da série era R$ 358705,97....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# 🔎 Pergunta: Há informações sobre séries temporais em 2002?
# --------------------------------------------------
#
# 💬 Resposta:
# Para dezembro de 2002, o dado disponível é que o valor da série era R$ 477899,39.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2002-12-01
# valor: 47789939
# contexto: No mês de dezembro de 2002, o valor da série era R$ 477899,39....
#
# 📄 Fonte 2:
# data: 2003-12-01
# valor: 50092791
# contexto: No mês de dezembro de 2003, o valor da série era R$ 500927,91....
#
# 📄 Fonte 3:
# data: 2001-12-01
# valor: 35870597
# contexto: No mês de dezembro de 2001, o valor da série era R$ 358705,97....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# 🔎 Pergunta: Há informações sobre séries temporais em 2002?
# --------------------------------------------------
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.325 - Relevância: 🟢 Alta
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.325 - Relevância: 🟢 Alta
#
# 💬 Resposta:
# Sim, há informações sobre séries temporais em 2002. Os dados fornecidos incluem valores mensais para o ano de 2002, conforme segue:
#
# - Janeiro: R$ 346.322,82
# - Fevereiro: R$ 332.562,58
# - Março: R$ 329.269,59
# - Abril: R$ 324.008,76
# - Maio: R$ 325.449,21
# - Agosto: R$ 367.391,90
# - Setembro: R$ 378.276,00
# - Outubro: R$ 396.658,84
# - Novembro: R$ 407.485,50
# - Dezembro: R$ 477.899,39
#
# Os dados para os meses de junho e julho não foram fornecidos no contexto.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2002-02-01
# valor: 33256258
# contexto: No mês de fevereiro de 2002, o valor da série era R$ 332562,58....
#
# 📄 Fonte 2:
# data: 2002-01-01
# valor: 34632282
# contexto: No mês de janeiro de 2002, o valor da série era R$ 346322,82....
#
# 📄 Fonte 3:
# data: 2002-08-01
# valor: 36739190
# contexto: No mês de agosto de 2002, o valor da série era R$ 367391,90....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# 🔎 Pergunta: Que tipo de dados financeiros estão disponíveis?
# --------------------------------------------------
#
# 💬 Resposta:
# Sim, há informações sobre séries temporais em 2002. Os dados fornecidos incluem valores mensais para o ano de 2002, conforme segue:
#
# - Janeiro: R$ 346.322,82
# - Fevereiro: R$ 332.562,58
# - Março: R$ 329.269,59
# - Abril: R$ 324.008,76
# - Maio: R$ 325.449,21
# - Agosto: R$ 367.391,90
# - Setembro: R$ 378.276,00
# - Outubro: R$ 396.658,84
# - Novembro: R$ 407.485,50
# - Dezembro: R$ 477.899,39
#
# Os dados para os meses de junho e julho não foram fornecidos no contexto.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2002-02-01
# valor: 33256258
# contexto: No mês de fevereiro de 2002, o valor da série era R$ 332562,58....
#
# 📄 Fonte 2:
# data: 2002-01-01
# valor: 34632282
# contexto: No mês de janeiro de 2002, o valor da série era R$ 346322,82....
#
# 📄 Fonte 3:
# data: 2002-08-01
# valor: 36739190
# contexto: No mês de agosto de 2002, o valor da série era R$ 367391,90....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# 🔎 Pergunta: Que tipo de dados financeiros estão disponíveis?
# --------------------------------------------------
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.366 - Relevância: 🟢 Alta
# 🔍 Busca direta encontrou 3 resultados
# 📊 Melhor score: 0.366 - Relevância: 🟢 Alta
#
# 💬 Resposta:
# Os dados financeiros disponíveis no contexto referem-se a valores de uma série temporal em diferentes datas. Esses valores são apresentados em reais (R$) e parecem representar algum tipo de indicador econômico ou financeiro ao longo do tempo. Os dados incluem:
#
# - Em dezembro de 2006, o valor era R$ 828.814,20.
# - Em agosto de 1986, o valor era R$ 577.300,00.
# - Em maio de 1998, o valor era R$ 173.773,85.
# - Em janeiro de 2005, o valor era R$ 586.706,45.
# - Em dezembro de 2004, o valor era R$ 611.975,08.
# - Em janeiro de 2008, o valor era R$ 951.815,72.
# - Em julho de 1996, o valor era R$ 124.183,00.
# - Em dezembro de 2000, o valor era R$ 308.146,00.
# - Em maio de 2005, o valor era R$ 543.354,48.
# - Em agosto de 1996, o valor era R$ 126.171,55.
#
# O contexto não especifica exatamente que tipo de indicador ou série financeira esses valores representam.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2006-12-01
# valor: 82881420
# contexto: No mês de dezembro de 2006, o valor da série era R$ 828814,20....
#
# 📄 Fonte 2:
# data: 1986-08-01
# valor: 57730000
# contexto: No mês de agosto de 1986, o valor da série era R$ 577300,00....
#
# 📄 Fonte 3:
# data: 1998-05-01
# valor: 17377385
# contexto: No mês de maio de 1998, o valor da série era R$ 173773,85....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# ✨ Testes concluídos!
# Use a função `ask_question('sua pergunta', qa_chain, vectorstore)` para novas consultas.
#
# 💬 Resposta:
# Os dados financeiros disponíveis no contexto referem-se a valores de uma série temporal em diferentes datas. Esses valores são apresentados em reais (R$) e parecem representar algum tipo de indicador econômico ou financeiro ao longo do tempo. Os dados incluem:
#
# - Em dezembro de 2006, o valor era R$ 828.814,20.
# - Em agosto de 1986, o valor era R$ 577.300,00.
# - Em maio de 1998, o valor era R$ 173.773,85.
# - Em janeiro de 2005, o valor era R$ 586.706,45.
# - Em dezembro de 2004, o valor era R$ 611.975,08.
# - Em janeiro de 2008, o valor era R$ 951.815,72.
# - Em julho de 1996, o valor era R$ 124.183,00.
# - Em dezembro de 2000, o valor era R$ 308.146,00.
# - Em maio de 2005, o valor era R$ 543.354,48.
# - Em agosto de 1996, o valor era R$ 126.171,55.
#
# O contexto não especifica exatamente que tipo de indicador ou série financeira esses valores representam.
#
# 📚 Baseado em 10 documento(s):
#
# 📄 Fonte 1:
# data: 2006-12-01
# valor: 82881420
# contexto: No mês de dezembro de 2006, o valor da série era R$ 828814,20....
#
# 📄 Fonte 2:
# data: 1986-08-01
# valor: 57730000
# contexto: No mês de agosto de 1986, o valor da série era R$ 577300,00....
#
# 📄 Fonte 3:
# data: 1998-05-01
# valor: 17377385
# contexto: No mês de maio de 1998, o valor da série era R$ 173773,85....
#
# ────────────────────────────────────────────────────────────
# ✅ Resposta obtida com sucesso
#
# ✨ Testes concluídos!
# Use a função `ask_question('sua pergunta', qa_chain, vectorstore)` para novas consultas.
